# %% [markdown]
# # Exercise 2, Page 52

# %% [markdown]
# Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction.
# Finally, provide n and p.
#
#
# (a) We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.
#
# this scenario is a regression problem since we are predicting an output value which is the CEO salary.
# n=5 , p=3
#
# (b) We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.
#
# This scenario is a classification problem since we are predicting a categorical label which is success or failure.
# n = 20, p = 13.
#
# (c)We are interested in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.
#
# This scenario is a regression problem since we are predicting an output value which is  USD/Euro exchange rate.
# n = 52, p = 3.

# %% [markdown]
# # Exercise 10, Page 56

# %% [markdown]
# How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
library("ISLR2")
library("ggplot2")

# %%
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio lstat
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3     4.98
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8     9.14
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8     4.03
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7     2.94
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7     5.33
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7     5.21
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    12.43
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    19.15
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    29.93
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    17.10
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    20.45
# ...

# %%
? Boston
#A data set containing housing values in 506 suburbs of Boston.
#Format: data frame with 506 rows and 13 variables.

# %% [markdown]
# Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %%
pairs(Boston)
# Out:
# plot without title

# %% [markdown]
# Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %%
head(cor(Boston),1)
# Out:
#      crim zn         indus     chas        nox       rm         age
# crim 1    -0.2004692 0.4065834 -0.05589158 0.4209717 -0.2192467 0.3527343
#      dis        rad       tax       ptratio   lstat     medv
# crim -0.3796701 0.6255051 0.5827643 0.2899456 0.4556215 -0.3883046

# %% [markdown]
# Do any of the census tracts of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08205   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %% [markdown]
# The highest recorded crime rate is 88% with the lowest being .006%. The crime rate data is significantly impacted by extreme values, as indicated by the low median and high average. The tax rates vary from 187 per $10,000 to 711. The average pupil-teacher ratio is 18.46, with a minimum of 12.6 and a maximum of 22.

# %% [markdown]
# How many of the census tracts in this data set bound the Charles river?

# %%
sum(Boston$chas == 1)
# Out:
# [1] 35

# %% [markdown]
# There are 35 census tracts bound by the charles river.

# %% [markdown]
# What is the median pupil-teacher ratio among the towns in this data set?

# %%
median(Boston$ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# Median pratio is 19.05

# %% [markdown]
# Which census tract of Boston has lowest median value of owneroccupied homes? What are the values of the other predictors for that census tract, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
#Sort the "medv" column in ascending order
Boston_sorted <- Boston[order(Boston$medv),]
Boston_sorted
# Out:
#     crim     zn   indus chas nox    rm    age   dis    rad tax ptratio lstat
# 399 38.35180 0    18.10 0    0.693  5.453 100.0 1.4896 24  666 20.2    30.59
# 406 67.92080 0    18.10 0    0.693  5.683 100.0 1.4254 24  666 20.2    22.98
# 401 25.04610 0    18.10 0    0.693  5.987 100.0 1.5888 24  666 20.2    26.77
# 400  9.91655 0    18.10 0    0.693  5.852  77.8 1.5004 24  666 20.2    29.97
# 415 45.74610 0    18.10 0    0.693  4.519 100.0 1.6582 24  666 20.2    36.98
# 490  0.18337 0    27.74 0    0.609  5.414  98.3 1.7554  4  711 20.1    23.97
# 386 16.81180 0    18.10 0    0.700  5.277  98.1 1.4261 24  666 20.2    30.81
# 402 14.23620 0    18.10 0    0.693  6.343 100.0 1.5741 24  666 20.2    20.32
# 416 18.08460 0    18.10 0    0.679  6.434 100.0 1.8347 24  666 20.2    29.05
# 388 22.59710 0    18.10 0    0.700  5.000  89.5 1.5184 24  666 20.2    31.99
# 417 10.83420 0    18.10 0    0.679  6.782  90.8 1.8195 24  666 20.2    25.79
# ...

# %%
Boston_sorted <- Boston_sorted[1:2,]
Boston_sorted
# Out:
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio lstat medv
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    30.59 5
# 406 67.9208 0  18.1  0    0.693 5.683 100 1.4254 24  666 20.2    22.98 5

# %% [markdown]
# selecting two census tracts with the lowest median value of owner-occupied homes, which was 5. Despite the low median home value, the crime rates in these areas were relatively high, with values of 38 and 67. The tax rates in this area were also surprisingly high. Additionally, the age of these homes appears to be at the maximum value of 100, which suggests that these are highly taxed, old homes with a high crime rate.

# %% [markdown]
# In this data set, how many of the census tracts average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the census tracts that average more than eight rooms per dwelling.

# %%
#Count the number of census tracts with more than 7 rooms per dwelling
rooms_7 <- sum(Boston$rm > 7)
rooms_7
#Count the number of census tracts with more than 8 rooms per dwelling
rooms_8 <- sum(Boston$rm > 8)
rooms_8
#Extract the census tracts with more than 8 rooms per dwelling
high_rooms <- Boston[Boston$rm > 8,]
summary(high_rooms)
# Out:
# [1] 64
# [1] 13
#       crim               zn            indus             chas
#  Min.   :0.02009   Min.   : 0.00   Min.   : 2.680   Min.   :0.0000
#  1st Qu.:0.33147   1st Qu.: 0.00   1st Qu.: 3.970   1st Qu.:0.0000
#  Median :0.52014   Median : 0.00   Median : 6.200   Median :0.0000
#  Mean   :0.71879   Mean   :13.62   Mean   : 7.078   Mean   :0.1538
#  3rd Qu.:0.57834   3rd Qu.:20.00   3rd Qu.: 6.200   3rd Qu.:0.0000
#  Max.   :3.47428   Max.   :95.00   Max.   :19.580   Max.   :1.0000
#       nox               rm             age             dis
#  Min.   :0.4161   Min.   :8.034   Min.   : 8.40   Min.   :1.801
#  1st Qu.:0.5040   1st Qu.:8.247   1st Qu.:70.40   1st Qu.:2.288
#  Median :0.5070   Median :8.297   Median :78.30   Median :2.894
#  Mean   :0.5392   Mean   :8.349   Mean   :71.54   Mean   :3.430
#  3rd Qu.:0.6050   3rd Qu.:8.398   3rd Qu.:86.50   3rd Qu.:3.652
#  Max.   :0.7180   Max.   :8.780   Max.   :93.90   Max.   :8.907
# ...

# %% [markdown]
# The result shows that there are 64 census tracts with 7 or more rooms per dwelling, but only 13 with 8 or more rooms per dwelling. The data also suggests that these 13 census tracts with 8 or more rooms per dwelling are in a safer neighborhood, with lower crime rates (mean of .718, maximum crime rate of 3.4), lower poverty levels (mean of 4.3, maximum lstat of 7.44), and more expensive homes (mean of 44, maximum median value of 50). These census tracts are considered to have a higher status compared to others.

# %% [markdown]
# # Exercise 3, Page 121

# %% [markdown]
# Suppose we have a data set with five predictors, X1 = GPA, X2 = IQ, X3 = Level (1 for College and 0 for High School), X4 = Interaction between GPA and IQ, and X5 = Interaction between GPA and Level. The response is starting salary after graduation (in thousands of dollars). Suppose we use least squares to fit the model, and get βˆ0 = 50, ˆβ1 = 20, ˆβ2 = 0.07, ˆβ3 = 35, ˆβ4 = 0.01, ˆβ5 = −10.
#
# (a) Which answer is correct, and why?
#
# i. For a fixed value of IQ and GPA, high school graduates earn more, on average, than college graduates.
#
# ii. For a fixed value of IQ and GPA, college graduates earn more, on average, than high school graduates.
#
# iii. For a fixed value of IQ and GPA, high school graduates earn more, on average, than college graduates provided that the GPA is high enough.
#
# iv. For a fixed value of IQ and GPA, college graduates earn more, on average, than high school graduates provided that the GPA is high enough.

# %% [markdown]
# (b) Predict the salary of a college graduate with IQ of 110 and a GPA of 4.0.

# %% [markdown]
# The model:
# 𝑌 = 𝛽0 + 𝛽1𝑋1 + 𝛽2𝑋2 + ⋯ + 𝛽𝑝𝑋𝑝 + �

# %% [markdown]
# ŷ = βˆ0 + ˆβ1 * GPA + ˆβ2 * IQ + ˆβ3 * Level + ˆβ4 * GPA * IQ + ˆβ5 * GPA * Level
#
# ŷ = 50 + 20 * 4.0 + 0.07 * 110 + 35 * 1 + 0.01 * 4.0 * 110 - 10 * 4.0 * 1
#
# ŷ = 50 + 80 + 7.7 + 35 + 4.4 - 40
#
# ŷ = 137.1
#
# So the predicted salary is $137,100.

# %% [markdown]
# (c) True or false: Since the coefficient for the GPA/IQ interaction term is very small, there is very little evidence of an interaction effect. Justify your answer.

# %% [markdown]
# FALSE, The significance of an interaction effect is not solely determined by the size of the coefficient for the interaction term. Other factors, including the relationship between predictors and response, should also be considered. Despite a seemingly small coefficient for the GPA/IQ interaction in this case, it still has a significant impact on the starting salary prediction and should not be disregarded.

# %% [markdown]
# #  Exercise 10, Page 124

# %% [markdown]
# Fit a multiple regression model to predict Sales using Price, Urban, and US.

# %%
head(Carseats)
# Out:
#   Sales CompPrice Income Advertising Population Price ShelveLoc Age Education
# 1  9.50 138        73    11          276        120   Bad       42  17
# 2 11.22 111        48    16          260         83   Good      65  10
# 3 10.06 113        35    10          269         80   Medium    59  12
# 4  7.40 117       100     4          466         97   Medium    55  14
# 5  4.15 141        64     3          340        128   Bad       38  13
# 6 10.81 124       113    13          501         72   Bad       78  16
#   Urban US
# 1 Yes   Yes
# 2 Yes   Yes
# 3 Yes   Yes
# 4 Yes   Yes
# 5 Yes   No
# 6 No    Yes

# %%
# load the Carseats data set
data(Carseats)
# fit the multiple regression model
model = lm(Sales ~ Price + Urban + US, data = Carseats)
summary(model)
# Out:
# Call:
# lm(formula = Sales ~ Price + Urban + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036  < 2e-16 ***
# Price       -0.054459   0.005242 -10.389  < 2e-16 ***
# UrbanYes    -0.021916   0.271650  -0.081    0.936
# USYes        1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 2.2e-16

# %% [markdown]
# Provide an interpretation of each coefficient in the model. Be careful—some of the variables in the model are qualitative!

# %% [markdown]
# -The Price coefficient shows the average impact of a one-unit change in Price on Sales, while keeping the values of other variables constant.
#
# -The Urban coefficient indicates the average Sales difference between stores in urban and non-urban areas.
#
# -The US coefficient demonstrates the average Sales difference between stores located in the US and those located outside the US.

# %% [markdown]
# Write out the model in equation form, being careful to handle the qualitative variables properly.

# %% [markdown]
# The model may be written as
#
# Sales=13.043469+(−0.054459)×Price+(−0.021916)×Urban_Yes+(1.200573)×US+ε
#
# Urban has two categories: "Yes" and "No", then a new variable Urban_Yes can be created with a value of 1 for "Yes" and 0 for "No"

# %% [markdown]
# For which of the predictors can you reject the null hypothesis H0 : βj = 0?

# %% [markdown]
# We can reject the null hypothesis for Price and US.

# %% [markdown]
# On the basis of your response to the previous question, fit a smaller model that only uses the predictors for which there is evidence of association with the outcome.

# %%
# fit the smaller model with only significant predictors
model_small = lm(Sales ~ Price + US, data = Carseats)

# view the summary of the smaller model
summary(model_small)
# Out:
# Call:
# lm(formula = Sales ~ Price + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652  < 2e-16 ***
# Price       -0.05448    0.00523 -10.416  < 2e-16 ***
# USYes        1.19964    0.25846   4.641 4.71e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 2.2e-16

# %% [markdown]
# How well do the models in (a) and (e) fit the data?

# %% [markdown]
# Based on RSE and R² both models fit the data.

# %% [markdown]
# Using the model from (e), obtain 95% confidence intervals for the coefficient(s).

# %%
confint(model_small)
# Out:
#             2.5 %       97.5 %
# (Intercept) 11.79032020 14.27126531
# Price       -0.06475984 -0.04419543
# USYes        0.69151957  1.70776632

# %% [markdown]
# Is there evidence of outliers or high leverage observations in the model from (e)?

# %%
plot(predict(model_small), rstudent(model_small))
# Out:
# plot without title
